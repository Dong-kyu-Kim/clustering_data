# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
cluster_df = pd.read_csv(
    Path("./exported_resources/restaurant_scaled_and_clustered.csv")
)

cluster_df
# Out:
#       cluster_id  cluster    id    rating  seating_capacity  \
# 0              0        0     0 -0.014202         -1.276714
# 1              1        1     1 -1.390099          0.907389
# 2              2        0     2  1.189708         -0.701950
# 3              3        0     3  0.673746         -1.506619
# 4              4        1     4  1.533682          1.597106
# ...          ...      ...   ...       ...               ...
# 8363        8363        0  8363 -1.046125         -0.357091
# 8364        8364        0  8364 -0.530163         -0.644473
# 8365        8365        1  8365  1.189708          1.597106
# 8366        8366        0  8366 -1.562086         -1.679048
# 8367        8367        0  8367 -0.014202         -1.564095
#
#       average_meal_price  marketing_budget  social_media_followers  \
# 0               1.819441         -0.544861               -0.686274
# 1              -1.380216          0.656375                0.351622
# 2               0.027437         -0.231400                0.058746
# 3               0.254838         -1.124106               -1.126017
# 4               1.958951          0.230572                0.213665
# ...                  ...               ...                     ...
# 8363           -0.910068         -1.159727               -1.336227
# 8364           -0.768466         -0.674191               -0.845917
# 8365           -0.071614          1.496473                1.489845
# 8366           -0.234841         -1.376191               -1.557816
# 8367            1.616454         -0.665971               -0.640002
#
#       chef_experience_years  number_of_reviews  ...  location_rural  \
# 0                  0.534421          -1.219380  ...            True
# 1                 -0.371987           0.036038  ...           False
# 2                  1.440830           1.190445  ...            True
# 3                  0.534421          -1.590955  ...            True
# 4                 -0.190705          -1.605385  ...           False
# ...                     ...                ...  ...             ...
# 8363               0.171858          -0.515913  ...           False
# 8364              -0.190705           0.685392  ...            True
# 8365              -0.734551          -0.313892  ...           False
# 8366              -1.640959           0.743112  ...            True
# 8367              -0.371987          -1.176090  ...            True
#
#       location_suburban  cuisine_american  cuisine_french  cuisine_indian  \
# 0                 False             False           False           False
# 1                 False             False           False           False
# 2                 False             False           False           False
# 3                 False             False           False           False
# 4                 False             False           False           False
# ...                 ...               ...             ...             ...
# 8363               True             False           False            True
# 8364              False             False           False            True
# 8365              False             False           False           False
# 8366              False              True           False           False
# 8367              False             False           False           False
#
#       cuisine_italian  cuisine_japanese  cuisine_mexican  \
# 0               False              True            False
# 1               False             False             True
# 2                True             False            False
# 3                True             False            False
# 4               False              True            False
# ...               ...               ...              ...
# 8363            False             False            False
# 8364            False             False            False
# 8365             True             False            False
# 8366            False             False            False
# 8367            False              True            False
#
#       parking_availability_no  parking_availability_yes
# 0                       False                      True
# 1                       False                      True
# 2                        True                     False
# 3                       False                      True
# 4                        True                     False
# ...                       ...                       ...
# 8363                    False                      True
# 8364                     True                     False
# 8365                    False                      True
# 8366                     True                     False
# 8367                    False                      True
#
# [8368 rows x 27 columns]

# %%
cluster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8368 entries, 0 to 8367
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cluster_id                8368 non-null   int64
#  1   cluster                   8368 non-null   int64
#  2   id                        8368 non-null   int64
#  3   rating                    8368 non-null   float64
#  4   seating_capacity          8368 non-null   float64
#  5   average_meal_price        8368 non-null   float64
#  6   marketing_budget          8368 non-null   float64
#  7   social_media_followers    8368 non-null   float64
#  8   chef_experience_years     8368 non-null   float64
#  9   number_of_reviews         8368 non-null   float64
#  10  avg_review_length         8368 non-null   float64
#  11  ambience_score            8368 non-null   float64
#  12  service_quality_score     8368 non-null   float64
#  13  weekend_reservations      8368 non-null   float64
#  14  weekday_reservations      8368 non-null   float64
#  15  revenue                   8368 non-null   float64
#  16  location_downtown         8368 non-null   bool
#  17  location_rural            8368 non-null   bool
#  18  location_suburban         8368 non-null   bool
#  19  cuisine_american          8368 non-null   bool
#  20  cuisine_french            8368 non-null   bool
#  21  cuisine_indian            8368 non-null   bool
#  22  cuisine_italian           8368 non-null   bool
#  23  cuisine_japanese          8368 non-null   bool
#  24  cuisine_mexican           8368 non-null   bool
#  25  parking_availability_no   8368 non-null   bool
#  26  parking_availability_yes  8368 non-null   bool
# dtypes: bool(11), float64(13), int64(3)
# memory usage: 1.1 MB

# %%
cluster_0 = cluster_df.loc[cluster_df["cluster"] == 0, "rating":"parking_availability_yes"]
cluster_0_avg = pd.DataFrame(cluster_0.mean())
cluster_0_avg = cluster_0_avg.transpose()
cluster_0_avg.to_csv(Path("./exported_resources/cluster_0_avg.csv"))
cluster_0_avg
# Out:
#      rating  seating_capacity  average_meal_price  marketing_budget  \
# 0 -0.065808         -0.564129           -0.074478         -0.484242
#
#    social_media_followers  chef_experience_years  number_of_reviews  \
# 0                -0.47748              -0.021411           0.002972
#
#    avg_review_length  ambience_score  service_quality_score  ...  \
# 0           0.023432        0.001527               0.003346  ...
#
#    location_rural  location_suburban  cuisine_american  cuisine_french  \
# 0        0.508013           0.444281          0.172592        0.160066
#
#    cuisine_indian  cuisine_italian  cuisine_japanese  cuisine_mexican  \
# 0        0.174434         0.165776           0.14312         0.184012
#
#    parking_availability_no  parking_availability_yes
# 0                 0.501013                  0.498987
#
# [1 rows x 24 columns]

# %%
cluster_0_std = pd.DataFrame(cluster_0.std())
cluster_0_std = cluster_0_std.transpose()
cluster_0_std.to_csv(Path("./exported_resources/cluster_0_std.csv"))
cluster_0_std
# Out:
#      rating  seating_capacity  average_meal_price  marketing_budget  \
# 0  0.997089          0.721548            0.987582          0.524584
#
#    social_media_followers  chef_experience_years  number_of_reviews  \
# 0                0.547067               1.002881           0.997291
#
#    avg_review_length  ambience_score  service_quality_score  ...  \
# 0           1.003957        0.994565               0.997494  ...
#
#    location_rural  location_suburban  cuisine_american  cuisine_french  \
# 0        0.499982           0.496931          0.377929        0.366701
#
#    cuisine_indian  cuisine_italian  cuisine_japanese  cuisine_mexican  \
# 0        0.379517         0.371914          0.350228         0.387529
#
#    parking_availability_no  parking_availability_yes
# 0                 0.500045                  0.500045
#
# [1 rows x 24 columns]

# %%
cluster_1 = cluster_df.loc[cluster_df["cluster"] == 1, "rating":"parking_availability_yes"]
cluster_1_avg = pd.DataFrame(cluster_1.mean())
cluster_1_avg = cluster_1_avg.transpose()
cluster_1_avg.to_csv(Path("./exported_resources/cluster_1_avg.csv"))
cluster_1_avg
# Out:
#      rating  seating_capacity  average_meal_price  marketing_budget  \
# 0  0.121562          1.042074            0.137578          0.894505
#
#    social_media_followers  chef_experience_years  number_of_reviews  \
# 0                0.882014               0.039551           -0.00549
#
#    avg_review_length  ambience_score  service_quality_score  ...  \
# 0          -0.043284       -0.002821               -0.00618  ...
#
#    location_rural  location_suburban  cuisine_american  cuisine_french  \
# 0        0.001361           0.126914          0.162981        0.191902
#
#    cuisine_indian  cuisine_italian  cuisine_japanese  cuisine_mexican  \
# 0        0.143586         0.174549          0.192923         0.134059
#
#    parking_availability_no  parking_availability_yes
# 0                 0.496427                  0.503573
#
# [1 rows x 24 columns]

# %%
cluster_1_std = pd.DataFrame(cluster_1.std())
cluster_1_std = cluster_1_std.transpose()
cluster_1_std.to_csv(Path("./exported_resources/cluster_1_std.csv"))
cluster_1_std
# Out:
#      rating  seating_capacity  average_meal_price  marketing_budget  \
# 0  0.994302          0.460398            1.008512          1.051696
#
#    social_media_followers  chef_experience_years  number_of_reviews  \
# 0                1.046789               0.993785             1.0053
#
#    avg_review_length  ambience_score  service_quality_score  ...  \
# 0           0.991534        1.010295               1.004923  ...
#
#    location_rural  location_suburban  cuisine_american  cuisine_french  \
# 0        0.036873           0.332933          0.369411        0.393863
#
#    cuisine_indian  cuisine_italian  cuisine_japanese  cuisine_mexican  \
# 0        0.350729         0.379646           0.39466         0.340774
#
#    parking_availability_no  parking_availability_yes
# 0                 0.500072                  0.500072
#
# [1 rows x 24 columns]
